# %%
from PIL import Image
from skimage.io import imread, imsave, imshow, show
import matplotlib.pylab as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
im = Image.open("./rmv.jpg")
im.show()

# %%
import imageio
im2 = imageio.imread("./rmv.jpg")
plt.imshow(im2)

# %%
print (im.width,im.height, im.mode, im.format)
# Out:
# 1199 849 RGB JPEG

# %%
import matplotlib.image as mpimg
im3 = mpimg.imread("./rmv.jpg")
plt.imshow(im3)
print (im3.shape)
# Out:
# (849, 1199, 3)

# %%
imu = im.resize((im.width*2, im.height*2))
plt.imshow(imu)

# %%
fig,ax = plt.subplots(1,2)
ax[0].imshow(im);
ax[1].imshow(imu);

# %%
import numpy as np
import cv2

# %%
im4 = cv2.imread("./rmv.jpg")
cv2.imshow("image,im4")##display
cv2.waitKey(0) ##wait indefinately for a key stroke
CV2.destroyAllWindows()##destroys all windows

# %%
im4 = cv2.imread ("./rmv.jpg",0)
cv2.imshow("image",im4)
cv2.waitKey(0)
cv2.destroyAllWindows()
